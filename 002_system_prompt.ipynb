# %%
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-sonnet-4-6"

# %%
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

def chat(messages, system_prompt=None, temperature=1.0, stop_sequences=None):

    params = {
        "model" : model,
        "max_tokens" : 1000,
        "messages" : messages,
        "temperature": temperature
    }

    if system_prompt:
        params["system"] = system_prompt

    if stop_sequences:
        params["stop_sequences"] = stop_sequences

    message = client.messages.create(**params)
    return message.content[0].text

# %%
messages = []
system_prompt = """
You are a patient math tutor.
Do not directly answer a student's questions.
Guide them to a solution step by step.
"""
while True:
    user_input = input("> ")
    print(">", user_input)

    add_user_message(messages, user_input)
    answer = chat(messages, system_prompt=system_prompt, temperature=0.0)

    add_assistant_message(messages, answer)
    print("---")
    print(answer)
    print("---")

# %%
messages = []

add_user_message(messages, "Generate a one sentance movie idea")
answer = chat(messages)

answer
# Out:
# "Here's a movie idea:\n\n**A deaf musician discovers she can suddenly hear — but only the last sounds a person made before they died, leading her to accidentally uncover a serial killer's secrets hidden in the echoes of his victims' final moments.**"

# %%
messages = []

add_user_message(messages, "Write a 1 sentence description of a fake database")

stream = client.messages.create(
    model = model,
    max_tokens = 1000,
    messages = messages,
    stream = True
)

for event in stream:
    print(event)

# %%
messages = []

add_user_message(messages, "Write a 1 sentence description of a fake database")

with client.messages.stream(
    model = model,
    max_tokens = 1000,
    messages = messages
) as stream:
    for text in stream.text_stream:
        # print(text, end="")
        pass

stream.get_final_message()

# %%
messages = []
system_prompt = """
Generate three different sample AWS CLI commands.  Each should be very short.
"""

add_user_message(messages, system_prompt)
add_assistant_message(messages, "```")

text = chat(messages, system_prompt=system_prompt, stop_sequences=["```"])
text.strip()
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[10], line 9
#       5
#       6 add_user_message(messages, system_prompt)
#       7 add_assistant_message(messages, "```")
#       8
# ----> 9 text = chat(messages, system_prompt=system_prompt, stop_sequences="```")
#      10 text.strip()
#
# Cell In[9], line 24, in chat(messages, system_prompt, temperature, stop_sequences)
#      20
#      21     if stop_sequences:
#      22         params["stop_sequences"] = stop_sequences
#      23
# ---> 24     message = client.messages.create(**params)
#      25     return message.content[0].text
#
# File ~/sourcecode/claude-api-course/.venv/lib/python3.14/site-packages/anthropic/_utils/_utils.py:294, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     292             msg = f"Missing required argument: {quote(missing[0])}"
#     293     raise TypeError(msg)
# ...

# %%
from IPhython.display import Markdown

Markdown(text)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from IPhython.display import Markdown
#       2
#       3 Markdown(text)
#
# ModuleNotFoundError: No module named 'IPhython'
