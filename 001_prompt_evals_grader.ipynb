# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}
"""

    messages = []
    add_user_message(messages, prompt)
    output = chat(messages)
    return output

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 6.666666666666667

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "# Extract AWS Account ID from ARN\n\nHere's a solution with explanation:\n\n```python\ndef extract_account_id(arn):\n    \"\"\"\n    Extract AWS account ID from an ARN string.\n    \n    ARN format: arn:partition:service:region:account-id:resource-type/resource-id\n    \n    Args:\n        arn (str): The ARN string\n        \n    Returns:\n        str: The account ID, or None if not present\n    \"\"\"\n    parts = arn.split(':')\n    \n    # ARN structure: arn:partition:service:region:account-id:resource\n    # Index:         0    1         2       3      4          5+\n    \n    if len(parts) >= 5:\n        account_id = parts[4]\n        # Return None if account ID is empty (common for S3 bucket ARNs)\n        return account_id if account_id else None\n    \n    return None\n\n\n# Test cases\ntest_arns = [\n    'arn:aws:s3:::my-bucket/path/to/object',  # S3 - no account ID\n    'arn:aws:iam::123456789012:user/Development/product_1/*',  # IAM - has account ID\n    'arn:aws:ec2:us-east-1:123456789012:instance/i-1234567890abcdef0',  # EC2 - has account ID\n    'arn:aws:rds:us-east-1:123456789012:db:mysql-db1',  # RDS - has account ID\n]\n\nfor arn in test_arns:\n    account_id = extract_account_id(arn)\n    print(f\"ARN: {arn}\")\n    print(f\"Account ID: {account_id}\\n\")\n```\n\n**Output:**\n```\nARN: arn:aws:s3:::my-bucket/path/to/object\nAccount ID: None\n\nARN: arn:aws:iam::123456789012:user/Development/product_1/*\nAccount ID: 123456789012\n\nARN: arn:aws:ec2:us-east-1:123456789012:instance/i-1234567890abcdef0\nAccount ID: 123456789012\n\nARN: arn:aws:rds:us-east-1:123456789012:db:mysql-db1\nAccount ID: 123456789012\n```\n\n## Key Points:\n\n- **ARN Format**: `arn:partition:service:region:account-id:resource`\n- **Account ID Position**: Index 4 (5th element) when split by `:`\n- **S3 Buckets**: Typically don't have an account ID (empty string at index 4)\n- **Other Services**: Usually contain a 12-digit account ID\n\nThe function returns `None` for S3 bucket ARNs (which have no account ID) and the actual account ID for other AWS services.",
#     "test_case": {
#       "task": "Extract the AWS account ID from an ARN string like 'arn:aws:s3:::my-bucket/path/to/object'",
#       "format": "regex"
#     },
#     "score": 6,
#     "reasoning": "The solution correctly solves the core task for well-formed ARNs and demonstrates understanding of AWS ARN structure across services. However, it lacks robustness for real-world use cases where input validation and explicit error handling are critical. The function treats all non-matches identically, making it difficult to distinguish between 'no account ID' (valid for S3) and 'malformed ARN' (error condition). For production code, input validation with regex or explicit error cases would be expected."
#   },
#   {
#     "output": "# S3 Bucket with Versioning Enabled - CloudFormation Template\n\n```json\n{\n  \"AWSTemplateFormatVersion\": \"2010-09-09\",\n  \"Description\": \"CloudFormation template for S3 bucket with versioning enabled\",\n  \"Resources\": {\n    \"MyS3Bucket\": {\n      \"Type\": \"AWS::S3::Bucket\",\n      \"Properties\": {\n        \"BucketName\": \"my-versioned-bucket-12345\",\n        \"VersioningConfiguration\": {\n          \"Status\": \"Enabled\"\n        },\n        \"PublicAccessBlockConfiguration\": {\n          \"BlockPublicAcls\": true,\n          \"BlockPublicPolicy\": true,\n          \"IgnorePublicAcls\": true,\n          \"RestrictPublicBuckets\": true\n        },\n        \"Tags\": [\n          {\n            \"Key\": \"Name\",\n            \"Value\": \"VersionedBucket\"\n          },\n          {\n            \"Key\": \"Environment\",\n            \"Value\": \"Production\"\n          }\n        ]\n      }\n    }\n  },\n  \"Outputs\": {\n    \"BucketName\": {\n      \"Description\": \"Name of the S3 bucket\",\n      \"Value\": {\n        \"Ref\": \"MyS3Bucket\"\n      }\n    },\n    \"BucketArn\": {\n      \"Description\": \"ARN of the S3 bucket\",\n      \"Value\": {\n        \"Fn::GetAtt\": [\n          \"MyS3Bucket\",\n          \"Arn\"\n        ]\n      }\n    }\n  }\n}\n```\n\n## Key Features:\n\n- **VersioningConfiguration**: Set to `Enabled` to maintain multiple versions of objects\n- **PublicAccessBlockConfiguration**: Added security best practices to block public access\n- **Tags**: Includes metadata for resource organization\n- **Outputs**: Provides bucket name and ARN for reference\n\n## Usage Notes:\n\n- Replace `\"my-versioned-bucket-12345\"` with your desired bucket name (must be globally unique)\n- Versioning enables you to recover previous versions of objects\n- Once enabled, versioning cannot be disabled (only suspended)",
#     "test_case": {
#       "task": "Create a JSON CloudFormation template snippet for an S3 bucket with versioning enabled",
#       "format": "json"
#     },
#     "score": 7,
#     "reasoning": "The solution correctly addresses the core requirement of creating an S3 bucket with versioning enabled and demonstrates good security awareness. The template is syntactically valid and well-documented. However, the hardcoded bucket name is a significant practical issue since S3 bucket names must be globally unique across all AWS accounts - this would fail in real deployments. The template could be enhanced with additional security and data protection features, though these are not strictly required by the original task."
#   },
#   {
#     "output": "# AWS S3 Bucket Name Validator\n\n```python\nimport re\n\ndef is_valid_s3_bucket_name(bucket_name: str) -> bool:\n    \"\"\"\n    Validates if a string is a valid AWS S3 bucket name according to AWS naming rules.\n    \n    AWS S3 Bucket Naming Rules:\n    1. Bucket names must be between 3 and 63 characters long\n    2. Bucket names can consist only of lowercase letters, numbers, dots (.), and hyphens (-)\n    3. Bucket names must start and end with a letter or number\n    4. Bucket names must not contain consecutive dots\n    5. Bucket names must not be formatted as an IP address (e.g., 192.168.1.1)\n    6. Bucket names must not start with \"xn--\" (reserved for internationalized domain names)\n    7. Bucket names must not end with \"-s3alias\" (reserved suffix)\n    \n    Args:\n        bucket_name (str): The bucket name to validate\n        \n    Returns:\n        bool: True if valid, False otherwise\n    \"\"\"\n    \n    # Check if bucket_name is a string\n    if not isinstance(bucket_name, str):\n        return False\n    \n    # Rule 1: Length must be between 3 and 63 characters\n    if len(bucket_name) < 3 or len(bucket_name) > 63:\n        return False\n    \n    # Rule 2: Only lowercase letters, numbers, dots, and hyphens allowed\n    if not re.match(r'^[a-z0-9.-]+$', bucket_name):\n        return False\n    \n    # Rule 3: Must start and end with a letter or number\n    if not re.match(r'^[a-z0-9].*[a-z0-9]$', bucket_name) and len(bucket_name) > 1:\n        # Single character case\n        if len(bucket_name) == 1 and not re.match(r'^[a-z0-9]$', bucket_name):\n            return False\n    \n    # For single character, it must be a letter or number\n    if len(bucket_name) == 1:\n        if not bucket_name.isalnum():\n            return False\n    \n    # Rule 4: Must not contain consecutive dots\n    if '..' in bucket_name:\n        return False\n    \n    # Rule 5: Must not be formatted as an IP address\n    if re.match(r'^(\\d+)\\.(\\d+)\\.(\\d+)\\.(\\d+)$', bucket_name):\n        return False\n    \n    # Rule 6: Must not start with \"xn--\"\n    if bucket_name.startswith('xn--'):\n        return False\n    \n    # Rule 7: Must not end with \"-s3alias\"\n    if bucket_name.endswith('-s3alias'):\n        return False\n    \n    return True\n\n\n# Test cases\nif __name__ == \"__main__\":\n    test_cases = [\n        # Valid bucket names\n        (\"my-bucket\", True),\n        (\"my-bucket-123\", True),\n        (\"mybucket\", True),\n        (\"my.bucket\", True),\n        (\"a\", True),\n        (\"ab\", True),\n        (\"abc\", True),\n        (\"my-bucket-2024\", True),\n        (\"bucket.with.dots\", True),\n        \n        # Invalid bucket names\n        (\"My-Bucket\", False),  # Contains uppercase\n        (\"my_bucket\", False),  # Contains underscore\n        (\"my bucket\", False),  # Contains space\n        (\"my-\", False),  # Ends with hyphen\n        (\"-mybucket\", False),  # Starts with hyphen\n        (\"my..bucket\", False),  # Consecutive dots\n        (\"192.168.1.1\", False),  # IP address format\n        (\"xn--bucket\", False),  # Starts with xn--\n        (\"my-bucket-s3alias\", False),  # Ends with -s3alias\n        (\"ab\", False),  # Too short (less than 3)\n        (\"a\" * 64, False),  # Too long (more than 63)",
#     "test_case": {
#       "task": "Write a Python function that validates if a string is a valid AWS S3 bucket name according to AWS naming rules",
#       "format": "python"
#     },
#     "score": 7,
#     "reasoning": "The solution correctly implements most AWS S3 bucket naming rules with good documentation and test coverage. However, there are critical logic issues in Rule 3 validation that could cause 2-character bucket names to be incorrectly rejected, and the IP address validation is incomplete. The code would benefit from simplifying the start/end validation logic and being more thorough with numeric pattern rejection. Despite these issues, the overall approach is sound and the function would work correctly for the majority of valid bucket names."
#   }
# ]
