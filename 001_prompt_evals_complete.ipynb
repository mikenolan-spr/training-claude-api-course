# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex",
        "solution_criteria": "Key criteria for evaluating the solution"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Criteria you should use to evaluate the solution:
<criteria>
{test_case["solution_criteria"]}
</criteria>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}

* Respond only with Python, JSON, or a plain Regex
* Do not add any comments or commentary or explanation
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```code")
    output = chat(messages, stop_sequences=["```"])
    return output

# %%
# Functions to validate the output structure
import re
import ast


def validate_json(text):
    try:
        json.loads(text.strip())
        return 10
    except json.JSONDecodeError:
        return 0


def validate_python(text):
    try:
        ast.parse(text.strip())
        return 10
    except SyntaxError:
        return 0


def validate_regex(text):
    try:
        re.compile(text.strip())
        return 10
    except re.error:
        return 0


def grade_syntax(response, test_case):
    format = test_case["format"]
    if format == "json":
        return validate_json(response)
    elif format == "python":
        return validate_python(response)
    else:
        return validate_regex(response)

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    model_score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    syntax_score = grade_syntax(output, test_case)

    score = (model_score + syntax_score) / 2

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 8.333333333333334

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "\nimport json\nimport sys\n\ndef extract_s3_buckets(template):\n    try:\n        if isinstance(template, str):\n            template = json.loads(template)\n        \n        resources = template.get('Resources', {})\n        s3_buckets = [\n            logical_id \n            for logical_id, resource in resources.items() \n            if resource.get('Type') == 'AWS::S3::Bucket'\n        ]\n        return s3_buckets\n    except (json.JSONDecodeError, TypeError, AttributeError):\n        return []\n\nif __name__ == '__main__':\n    if len(sys.argv) > 1:\n        with open(sys.argv[1], 'r') as f:\n            template = f.read()\n    else:\n        template = sys.stdin.read()\n    \n    result = extract_s3_buckets(template)\n    print(json.dumps(result))\n",
#     "test_case": {
#       "task": "Parse an AWS CloudFormation template and extract all resource logical IDs that have a type of 'AWS::S3::Bucket'",
#       "format": "python",
#       "solution_criteria": "Function should accept a CloudFormation template dictionary as input and return a list of logical IDs for S3 buckets. Should handle templates with no S3 buckets gracefully."
#     },
#     "score": 8.5,
#     "reasoning": "The core function `extract_s3_buckets()` correctly fulfills the primary requirement - it accepts a template (string or dict), properly extracts S3 bucket logical IDs, and handles empty/missing buckets gracefully. The implementation is clean and uses appropriate Python idioms. However, the criteria explicitly states the function should accept a 'CloudFormation template dictionary,' yet the solution also adds CLI file-reading capability that goes beyond scope. Additionally, silent exception handling could hide real problems. The solution works well in practice but has minor design misalignments with the stated requirements."
#   },
#   {
#     "output": "\n{\n  \"FunctionName\": \"S3EventProcessor\",\n  \"Runtime\": \"python3.11\",\n  \"Role\": \"arn:aws:iam::ACCOUNT_ID:role/lambda-execution-role\",\n  \"Handler\": \"index.lambda_handler\",\n  \"Timeout\": 60,\n  \"MemorySize\": 256,\n  \"Environment\": {\n    \"Variables\": {\n      \"DYNAMODB_TABLE_NAME\": \"s3-events-table\",\n      \"SNS_TOPIC_ARN\": \"arn:aws:sns:us-east-1:ACCOUNT_ID:s3-events-topic\"\n    }\n  },\n  \"Events\": {\n    \"S3Event\": {\n      \"Type\": \"S3\",\n      \"Properties\": {\n        \"Bucket\": \"my-source-bucket\",\n        \"Events\": [\"s3:ObjectCreated:*\", \"s3:ObjectRemoved:*\"]\n      }\n    }\n  }\n}\n",
#     "test_case": {
#       "task": "Create a JSON configuration object for an AWS Lambda function that processes S3 events, with environment variables for a DynamoDB table name and SNS topic ARN",
#       "format": "json",
#       "solution_criteria": "JSON object should include handler, runtime, timeout, memory, environment variables section with DynamoDB_TABLE and SNS_TOPIC_ARN keys, and a basic S3 event source mapping structure."
#     },
#     "score": 8.5,
#     "reasoning": "The solution successfully addresses the core requirement by including all specified fields (handler, runtime, timeout, memory, environment variables with correct keys, and S3 event structure). The configuration is well-formatted and realistic. However, the Events section structure appears to be SAM-specific rather than pure Lambda configuration, which may cause issues depending on the deployment tool. The placeholder values are practical but could benefit from clearer documentation about required customization."
#   },
#   {
#     "output": "\n^arn:aws:iam::\\d{12}:role/[a-zA-Z0-9+=,.@\\-_/]+$\n",
#     "test_case": {
#       "task": "Write a regex pattern that validates AWS IAM role ARN format (arn:aws:iam::account-id:role/role-name)",
#       "format": "regex",
#       "solution_criteria": "Pattern should match valid IAM role ARNs with proper account ID (12 digits) and role name containing alphanumeric characters, hyphens, and forward slashes. Should reject malformed ARNs."
#     },
#     "score": 8.0,
#     "reasoning": "The pattern correctly handles the ARN structure and account ID validation, but the character class is overly permissive. AWS IAM role names support only alphanumeric characters plus hyphen, underscore, and forward slash for path notation. The inclusion of '+', '=', and ',' is incorrect and would accept invalid ARNs. The pattern also lacks constraints on slash placement (e.g., preventing '//role' or 'role/'). A more accurate pattern would be: ^arn:aws:iam::\\d{12}:role/[a-zA-Z0-9\\-_]+(/[a-zA-Z0-9\\-_]+)*$"
#   }
# ]
