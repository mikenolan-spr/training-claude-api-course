# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
# model = "claude-haiku-4-5"
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])

    return json.loads(text)

# %%
def run_prompt(test_case):
    """Merges the prompt and test case input, then returns the result"""
    prompt = f"""
Please solve the following task:

{test_case["task"]}
"""
    
    messages = []
    add_user_message(messages, prompt)
    output = chat(messages)
    return output

def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    # TODO - Grading
    score = 10

    return {
        "output": output,
        "test_case": test_case,
        "score": score
    }

def run_eval(dataset):
    """Loads the dataset"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    return results

# %%
dataset = generate_dataset()
dataset

with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
results
# Out:
# [{'output': '# AWS Region Extractor from S3 URL\n\nHere\'s a Python function that extracts the AWS region from an S3 bucket URL:\n\n```python\nimport re\n\ndef extract_aws_region(s3_url):\n    """\n    Extracts the AWS region from an S3 bucket URL.\n    \n    Supports formats:\n    - s3://bucket-name.region.amazonaws.com\n    - https://bucket-name.s3.region.amazonaws.com\n    - https://s3.region.amazonaws.com/bucket-name\n    - s3://bucket-name (returns \'us-east-1\' as default)\n    \n    Args:\n        s3_url (str): The S3 bucket URL\n        \n    Returns:\n        str: The AWS region name, or None if not found\n        \n    Raises:\n        ValueError: If the URL format is invalid\n    """\n    \n    if not isinstance(s3_url, str) or not s3_url.strip():\n        raise ValueError("URL must be a non-empty string")\n    \n    s3_url = s3_url.strip()\n    \n    # Pattern 1: s3://bucket-name.region.amazonaws.com\n    pattern1 = r\'s3://[^.]+\\.([a-z0-9\\-]+)\\.amazonaws\\.com\'\n    match = re.search(pattern1, s3_url)\n    if match:\n        return match.group(1)\n    \n    # Pattern 2: https://bucket-name.s3.region.amazonaws.com\n    pattern2 = r\'https?://[^.]+\\.s3\\.([a-z0-9\\-]+)\\.amazonaws\\.com\'\n    match = re.search(pattern2, s3_url)\n    if match:\n        return match.group(1)\n    \n    # Pattern 3: https://s3.region.amazonaws.com/bucket-name\n    pattern3 = r\'https?://s3\\.([a-z0-9\\-]+)\\.amazonaws\\.com\'\n    match = re.search(pattern3, s3_url)\n    if match:\n        return match.group(1)\n    \n    # Pattern 4: https://bucket-name.s3.amazonaws.com (us-east-1 default)\n    pattern4 = r\'https?://[^.]+\\.s3\\.amazonaws\\.com\'\n    if re.search(pattern4, s3_url):\n        return \'us-east-1\'\n    \n    # Pattern 5: s3://bucket-name (no region specified, return default)\n    pattern5 = r\'s3://[a-z0-9\\-.]+\'\n    if re.search(pattern5, s3_url):\n        return \'us-east-1\'\n    \n    raise ValueError(f"Unable to extract region from URL: {s3_url}")\n\n\n# Test cases\nif __name__ == "__main__":\n    test_cases = [\n        ("s3://my-bucket.us-west-2.amazonaws.com", "us-west-2"),\n        ("s3://my-bucket.eu-west-1.amazonaws.com", "eu-west-1"),\n        ("https://my-bucket.s3.us-east-1.amazonaws.com", "us-east-1"),\n        ("https://my-bucket.s3.ap-southeast-1.amazonaws.com", "ap-southeast-1"),\n        ("https://s3.eu-central-1.amazonaws.com/my-bucket", "eu-central-1"),\n        ("https://my-bucket.s3.amazonaws.com", "us-east-1"),\n        ("s3://my-bucket", "us-east-1"),\n    ]\n    \n    print("Testing AWS Region Extraction:\\n")\n    for url, expected in test_cases:\n        try:\n            result = extract_aws_region(url)\n            status = "✓ PASS" if result == expected else "✗ FAIL"\n            print(f"{status}: {url}")\n            print(f"  Expected: {expected}, Got: {result}\\n")\n        except ValueError as e:\n            print(f"',
#   'test_case': {'task': "Write a Python function that extracts the AWS region from an S3 bucket URL in the format 's3://bucket-name.region.amazonaws.com'. The function should return the region name."},
#   'score': 10},
#  {'output': '# AWS IAM Policy for S3 GetObject and PutObject\n\nHere\'s the JSON object that represents the IAM policy:\n\n```json\n{\n  "Version": "2012-10-17",\n  "Statement": [\n    {\n      "Effect": "Allow",\n      "Action": [\n        "s3:GetObject",\n        "s3:PutObject"\n      ],\n      "Resource": "arn:aws:s3:::my-app-bucket/*"\n    }\n  ]\n}\n```\n\n## Explanation\n\n- **Version**: "2012-10-17" is the standard IAM policy language version\n- **Statement**: Contains the policy rules\n  - **Effect**: "Allow" grants the specified permissions\n  - **Action**: \n    - `s3:GetObject` - Allows reading/downloading objects\n    - `s3:PutObject` - Allows writing/uploading objects\n  - **Resource**: \n    - `arn:aws:s3:::my-app-bucket/*` - Applies only to objects within the specific bucket\n    - The `/*` at the end means all objects in the bucket\n\n## Additional Notes\n\nIf you also need to list bucket contents, you might want to add `s3:ListBucket` with a different Resource ARN:\n\n```json\n{\n  "Version": "2012-10-17",\n  "Statement": [\n    {\n      "Effect": "Allow",\n      "Action": [\n        "s3:GetObject",\n        "s3:PutObject"\n      ],\n      "Resource": "arn:aws:s3:::my-app-bucket/*"\n    },\n    {\n      "Effect": "Allow",\n      "Action": "s3:ListBucket",\n      "Resource": "arn:aws:s3:::my-app-bucket"\n    }\n  ]\n}\n```\n\nThis follows the principle of least privilege by restricting access to only the necessary actions and resources.',
#   'test_case': {'task': "Create a JSON object that represents an AWS IAM policy allowing a user to perform only 'GetObject' and 'PutObject' actions on a specific S3 bucket named 'my-app-bucket'."},
#   'score': 10},
#  {'output': "# AWS EC2 Instance ID Regular Expression\n\nHere's the correct regular expression:\n\n```regex\n^i-[0-9a-f]{17}$\n```\n\n## Explanation\n\n- `^` - Start of string anchor\n- `i-` - Literal prefix (required for EC2 instance IDs)\n- `[0-9a-f]{17}` - Exactly 17 hexadecimal characters (0-9, a-f)\n- `$` - End of string anchor\n\n## Examples\n\n```regex\n^i-[0-9a-f]{17}$\n```\n\n### Valid Matches ✓\n- `i-0a1b2c3d4e5f6a7b8`\n- `i-1234567890abcdef0`\n- `i-ffffffffffffffff0`\n\n### Invalid Matches ✗\n- `i-0a1b2c3d4e5f6g7h8` (contains 'g' and 'h', not hexadecimal)\n- `i-0a1b2c3d4e5f6a7` (only 16 characters)\n- `0a1b2c3d4e5f6a7b8` (missing 'i-' prefix)\n\n## Usage Examples\n\n**JavaScript:**\n```javascript\nconst regex = /^i-[0-9a-f]{17}$/;\nconsole.log(regex.test('i-0a1b2c3d4e5f6a7b8')); // true\nconsole.log(regex.test('i-0a1b2c3d4e5f6g7h8')); // false\n```\n\n**Python:**\n```python\nimport re\nregex = r'^i-[0-9a-f]{17}$'\nprint(re.match(regex, 'i-0a1b2c3d4e5f6a7b8'))  # Match object\nprint(re.match(regex, 'i-0a1b2c3d4e5f6g7h8'))  # None\n```",
#   'test_case': {'task': "Write a regular expression that matches valid AWS EC2 instance IDs, which follow the format 'i-' followed by 17 hexadecimal characters (e.g., i-0a1b2c3d4e5f6g7h8)."},
#   'score': 10}]
